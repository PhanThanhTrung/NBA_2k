# %%
import numpy as np
import keras
from model import mobilenet_unet
from data_preprocessing import load_data
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
X,y=load_data()
# Out:
# [INFO] Loading on image path:  image108
# [INFO] Loading on image path:  image120
# [INFO] Loading on image path:  image63
# [INFO] Loading on image path:  image77
# [INFO] Loading on image path:  image88
# [INFO] Loading on image path:  image89
# [INFO] Loading on image path:  image76
# [INFO] Loading on image path:  image62
# [INFO] Loading on image path:  image121
# [INFO] Loading on image path:  image109
# [INFO] Loading on image path:  image123
# [INFO] Loading on image path:  image74
# [INFO] Loading on image path:  image60
# [INFO] Loading on image path:  image48
# [INFO] Loading on image path:  image49
# [INFO] Loading on image path:  image61
# [INFO] Loading on image path:  image75
# [INFO] Loading on image path:  image122
# [INFO] Loading on image path:  image126
# [INFO] Loading on image path:  image8
# [INFO] Loading on image path:  image59
# [INFO] Loading on image path:  image71
# [INFO] Loading on image path:  image65
# [INFO] Loading on image path:  image64
# [INFO] Loading on image path:  image70
# [INFO] Loading on image path:  image58
# [INFO] Loading on image path:  image9
# [INFO] Loading on image path:  image127
# [INFO] Loading on image path:  image131
# [INFO] Loading on image path:  image125
# [INFO] Loading on image path:  image119
# [INFO] Loading on image path:  image66
# [INFO] Loading on image path:  image72
# [INFO] Loading on image path:  image99
# [INFO] Loading on image path:  image98
# [INFO] Loading on image path:  image73
# [INFO] Loading on image path:  image67
# [INFO] Loading on image path:  image118
# [INFO] Loading on image path:  image124
# [INFO] Loading on image path:  image130
# [INFO] Loading on image path:  image14
# [INFO] Loading on image path:  image28
# [INFO] Loading on image path:  image29
# [INFO] Loading on image path:  image15
# [INFO] Loading on image path:  image17
# [INFO] Loading on image path:  image16
# [INFO] Loading on image path:  image12
# [INFO] Loading on image path:  image13
# [INFO] Loading on image path:  image39
# [INFO] Loading on image path:  image11
# [INFO] Loading on image path:  image10
# [INFO] Loading on image path:  image38
# [INFO] Loading on image path:  image21
# [INFO] Loading on image path:  image35
# [INFO] Loading on image path:  image34
# [INFO] Loading on image path:  image20
# [INFO] Loading on image path:  image36
# [INFO] Loading on image path:  image22
# [INFO] Loading on image path:  image23
# [INFO] Loading on image path:  image37
# [INFO] Loading on image path:  image33
# [INFO] Loading on image path:  image27
# [INFO] Loading on image path:  image26
# [INFO] Loading on image path:  image32
# [INFO] Loading on image path:  image18
# [INFO] Loading on image path:  image24
# [INFO] Loading on image path:  image30
# [INFO] Loading on image path:  image31
# [INFO] Loading on image path:  image25
# [INFO] Loading on image path:  image19
# [INFO] Loading on image path:  image129
# [INFO] Loading on image path:  image115
# [INFO] Loading on image path:  image101
# [INFO] Loading on image path:  image7
# [INFO] Loading on image path:  image42
# [INFO] Loading on image path:  image56
# [INFO] Loading on image path:  image81
# [INFO] Loading on image path:  image95
# [INFO] Loading on image path:  image94
# [INFO] Loading on image path:  image80
# [INFO] Loading on image path:  image57
# [INFO] Loading on image path:  image43
# [INFO] Loading on image path:  image6
# [INFO] Loading on image path:  image100
# [INFO] Loading on image path:  image114
# [INFO] Loading on image path:  image128
# [INFO] Loading on image path:  image102
# [INFO] Loading on image path:  image4
# [INFO] Loading on image path:  image116
# [INFO] Loading on image path:  image55
# [INFO] Loading on image path:  image41
# [INFO] Loading on image path:  image69
# [INFO] Loading on image path:  image96
# [INFO] Loading on image path:  image82
# [INFO] Loading on image path:  image83
# [INFO] Loading on image path:  image97
# [INFO] Loading on image path:  image68
# [INFO] Loading on image path:  image40
# [INFO] Loading on image path:  image54
# [INFO] Loading on image path:  image117
# [INFO] Loading on image path:  image5
# [INFO] Loading on image path:  image103
# [INFO] Loading on image path:  image107
# [INFO] Loading on image path:  image1
# [INFO] Loading on image path:  image113
# [INFO] Loading on image path:  image78
# [INFO] Loading on image path:  image50
# [INFO] Loading on image path:  image44
# [INFO] Loading on image path:  image93
# [INFO] Loading on image path:  image87
# [INFO] Loading on image path:  image86
# [INFO] Loading on image path:  image92
# [INFO] Loading on image path:  image45
# [INFO] Loading on image path:  image51
# [INFO] Loading on image path:  image79
# [INFO] Loading on image path:  image112
# [INFO] Loading on image path:  image106
# [INFO] Loading on image path:  image110
# [INFO] Loading on image path:  image104
# [INFO] Loading on image path:  image2
# [INFO] Loading on image path:  image47
# [INFO] Loading on image path:  image53
# [INFO] Loading on image path:  image84
# [INFO] Loading on image path:  image90
# [INFO] Loading on image path:  image91
# [INFO] Loading on image path:  image85
# [INFO] Loading on image path:  image52
# [INFO] Loading on image path:  image46
# [INFO] Loading on image path:  image3
# [INFO] Loading on image path:  image105
# [INFO] Loading on image path:  image111

# %%
y=np.array(y)
print(y.shape)
y=np.reshape(y,(-1,y.shape[1]*y.shape[2]))
y=to_categorical(y,num_classes=8)
# Out:
# (131, 720, 1280)

# %%
y.shape
# Out:
# (131, 921600, 8)

# %%
X=np.array(X)
X.shape
# Out:
# (131, 720, 1280, 3)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
aug = ImageDataGenerator(
		rotation_range=20,
		zoom_range=0.15,
		width_shift_range=0.2,
		height_shift_range=0.2,
		shear_range=0.15,
		horizontal_flip=True,
		fill_mode="nearest")

# %%
model=mobilenet_unet(8,720,1280,3)

# %%
model.summary()
#adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss="categorical_crossentropy",optimizer="adam", metrics=["accuracy"])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 720, 1280, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 722, 1282, 3) 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 360, 640, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 360, 640, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 360, 640, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_1 (ZeroPadding2D)      (None, 362, 642, 32) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 360, 640, 32) 288         conv_pad_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 360, 640, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (Activation)     (None, 360, 640, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 360, 640, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 360, 640, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (Activation)     (None, 360, 640, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 362, 642, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 180, 320, 64) 576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 180, 320, 64) 256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (Activation)     (None, 180, 320, 64) 0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 180, 320, 128 8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 180, 320, 128 512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (Activation)     (None, 180, 320, 128 0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_3 (ZeroPadding2D)      (None, 182, 322, 128 0           conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 180, 320, 128 1152        conv_pad_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 180, 320, 128 512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (Activation)     (None, 180, 320, 128 0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 180, 320, 128 16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 180, 320, 128 512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (Activation)     (None, 180, 320, 128 0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 182, 322, 128 0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 90, 160, 128) 1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 90, 160, 128) 512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (Activation)     (None, 90, 160, 128) 0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 90, 160, 256) 32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 90, 160, 256) 1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (Activation)     (None, 90, 160, 256) 0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_5 (ZeroPadding2D)      (None, 92, 162, 256) 0           conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 90, 160, 256) 2304        conv_pad_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 90, 160, 256) 1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (Activation)     (None, 90, 160, 256) 0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 90, 160, 256) 65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 90, 160, 256) 1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (Activation)     (None, 90, 160, 256) 0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 92, 162, 256) 0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 45, 80, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 45, 80, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (Activation)     (None, 45, 80, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 45, 80, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (Activation)     (None, 45, 80, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_7 (ZeroPadding2D)      (None, 47, 82, 512)  0           conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 45, 80, 512)  4608        conv_pad_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (Activation)     (None, 45, 80, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 45, 80, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (Activation)     (None, 45, 80, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_8 (ZeroPadding2D)      (None, 47, 82, 512)  0           conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 45, 80, 512)  4608        conv_pad_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (Activation)     (None, 45, 80, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 45, 80, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (Activation)     (None, 45, 80, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_9 (ZeroPadding2D)      (None, 47, 82, 512)  0           conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 45, 80, 512)  4608        conv_pad_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (Activation)     (None, 45, 80, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 45, 80, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 45, 80, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (Activation)     (None, 45, 80, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_10 (ZeroPadding2D)     (None, 47, 82, 512)  0           conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 45, 80, 512)  4608        conv_pad_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 45, 80, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (Activation)    (None, 45, 80, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 45, 80, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 45, 80, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (Activation)    (None, 45, 80, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_11 (ZeroPadding2D)     (None, 47, 82, 512)  0           conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 45, 80, 512)  4608        conv_pad_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 45, 80, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (Activation)    (None, 45, 80, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 45, 80, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 45, 80, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (Activation)    (None, 45, 80, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 47, 82, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 45, 80, 512)  2359808     zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 45, 80, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 90, 160, 512) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 90, 160, 768) 0           up_sampling2d_1[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 92, 162, 768) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 90, 160, 256) 1769728     zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 90, 160, 256) 1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 180, 320, 256 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 180, 320, 384 0           up_sampling2d_2[0][0]
#                                                                  conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 182, 322, 384 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 180, 320, 128 442496      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 180, 320, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 360, 640, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 360, 640, 192 0           up_sampling2d_3[0][0]
#                                                                  conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 362, 642, 192 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 360, 640, 64) 110656      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 360, 640, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 720, 1280, 64 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 720, 1280, 8) 4616        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 921600, 8)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 921600, 8)    0           reshape_1[0][0]
# ==================================================================================================
# Total params: 6,318,984
# Trainable params: 6,302,344
# Non-trainable params: 16,640
# __________________________________________________________________________________________________

# %%
model.fit(
	x=aug.flow(X_train, y_train, batch_size=4),
	validation_data=(X_test, y_test),
	epochs=5, verbose=True)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1862s 72s/step - loss: 1.6630 - accuracy: 0.5771 - val_loss: 8.7504 - val_accuracy: 0.3521
# Epoch 2/5
# 26/26 [==============================] - 2406s 93s/step - loss: 1.1706 - accuracy: 0.6598 - val_loss: 10.6886 - val_accuracy: 0.2489
# Epoch 3/5
# 26/26 [==============================] - 1649s 63s/step - loss: 0.9972 - accuracy: 0.6707 - val_loss: 2.7856 - val_accuracy: 0.5941
# Epoch 4/5
# 26/26 [==============================] - 1433s 55s/step - loss: 1.0022 - accuracy: 0.6696 - val_loss: 8.0175 - val_accuracy: 0.3956
# Epoch 5/5
# 26/26 [==============================] - 1368s 53s/step - loss: 0.9741 - accuracy: 0.6743 - val_loss: 3.1413 - val_accuracy: 0.5272

# %%
model.save("./sample")
